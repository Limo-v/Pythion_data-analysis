# %% [markdown]
# In this Notebook,I are going to collect Formula One drivers' statistics in the year 2000's.
# I'll then mo going to analyse the Number of Wins per driver, number of wins per constructor , Hamilton, Schumacher and Verstappen results, average finishing position in 2022 , and the experience of current drivers over the years.
#
# maybe : Can compare if nationality of winner matches that of driver

# %%
import json
import urllib
from pathlib import Path
from datetime import datetime
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
from collections import OrderedDict
import numpy as np
import glob

# %% [markdown]
# This notebook covers **Task 1 - Data Collection**. Lucklily from this API, We only need to run this once to get the data.

# %%
#Create directory for raw data storage, if it does not already exist:
dir_raw = Path("raw")
dir_raw.mkdir(parents=True, exist_ok=True)

# %%
#This convenient function will read in the data of a given year between 2000 to 2022
def read_and_parse_race_year(race_year):
    response = requests.get("http://ergast.com/api/f1/"+str(race_year)+"/results/1.json") 
    jdata = response.text
    data = json.loads(jdata) 
    return(data)

# %%
#This convenient function will read in the data of a driver by the driver name 
def read_and_parse_driver_data(driver_name):
    response = requests.get("http://ergast.com/api/f1/drivers/"+str(driver_name)+"/results.json") 
    jdata = response.text
    data = json.loads(jdata) 
    return(data)

# %%
response = requests.get("http://ergast.com/api/f1/drivers/hamilton/results.json") 
jdata = response.text
data = json.loads(jdata)
data
#data['MRData']['RaceTable']['Races']
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/drivers/hamilton/results.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '308',
#   'RaceTable': {'driverId': 'hamilton',
#    'Races': [{'season': '2007',
#      'round': '1',
#      'url': 'http://en.wikipedia.org/wiki/2007_Australian_Grand_Prix',
#      'raceName': 'Australian Grand Prix',
#      'Circuit': {'circuitId': 'albert_park',
#       'url': 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit',
#       'circuitName': 'Albert Park Grand Prix Circuit',
#       'Location': {'lat': '-37.8497',
#        'long': '144.968',
#        'locality': 'Melbourne',
#        'country': 'Australia'}},
#      'date': '2007-03-18',
#      'time': '03:00:00Z',
#      'Results': [{'number': '2',
#        'position': '3',
#        'positionText': '3',
#        'points': '6',
#        'Driver': {'driverId': 'hamilton',
#         'permanentNumber': '44',
# ...

# %%
#
fname = "yearframe.json" 
out_path = dir_raw / fname
print("Writing data to %s" % out_path)
fout = open(out_path, "w")
conditions_data = list_of_races 
json.dump(conditions_data, fout, indent=4, sort_keys=True)
fout.close()
# Out:
# Writing data to raw/yearframe.json

# %%
fname = "driverdata.json" 
out_path = dir_raw / fname
print("Writing data to %s" % out_path)
fout = open(out_path, "w")
conditions_data = list_of_drivers
json.dump(conditions_data, fout, indent=4, sort_keys=True)
fout.close()
# Out:
# Writing data to raw/driverdata.json

# %% [markdown]
# I made the directories yearframe.json and driverdata.json and put all the data their in the correct format.
